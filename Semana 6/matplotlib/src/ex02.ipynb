# %% [markdown]
# # ex02.py – Curvas de treino e validação (accuracy e loss)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../datasets/metrics.csv")

# %%
df
# Out:
#     train_loss  val_loss  train_acc   val_acc
# 0     1.299380  1.037020   0.397652  0.604396
# 1     1.019229  0.745705   0.589824  0.703297
# 2     0.793183  0.611423   0.684932  0.747253
# 3     0.649150  0.524193   0.749902  0.769231
# 4     0.568477  0.444665   0.772211  0.791209
# 5     0.470972  0.457897   0.824266  0.802198
# 6     0.407660  0.414588   0.847750  0.791209
# 7     0.363528  0.372818   0.862622  0.824176
# 8     0.326244  0.342653   0.884932  0.846154
# 9     0.300462  0.348851   0.895890  0.824176
# 10    0.263265  0.336168   0.919374  0.813187
# 11    0.225053  0.286972   0.927202  0.857143
# 12    0.204362  0.315119   0.931507  0.846154
# 13    0.178455  0.255434   0.937378  0.868132
# 14    0.143337  0.297552   0.955773  0.868132
# 15    0.129189  0.226588   0.960470  0.890110
# 16    0.125346  0.277214   0.958121  0.890110
# 17    0.103721  0.258499   0.967906  0.868132
# 18    0.086152  0.243292   0.974168  0.857143
# 19    0.085143  0.264422   0.976517  0.890110
# 20    0.070637  0.204474   0.980822  0.901099
# 21    0.058165  0.196024   0.986301  0.923077
# 22    0.056913  0.214620   0.986693  0.901099
# 23    0.056738  0.266681   0.985127  0.868132
# 24    0.050898  0.286884   0.985519  0.879121
# 25    0.047177  0.272411   0.986693  0.879121
# 26    0.038619  0.268742   0.990607  0.901099
# 27    0.036813  0.223092   0.990607  0.912088
# 28    0.026853  0.282221   0.995695  0.901099
# 29    0.030304  0.245861   0.992955  0.934066
# 30    0.031224  0.292102   0.990607  0.901099
# 31    0.031496  0.358251   0.990607  0.890110
# 32    0.035407  0.319495   0.989432  0.912088
# 33    0.022706  0.206473   0.995303  0.923077
# 34    0.026327  0.263084   0.992172  0.912088
# 35    0.022691  0.220622   0.993346  0.934066
# 36    0.020472  0.195730   0.994129  0.934066
# 37    0.020562  0.219799   0.993738  0.934066
# 38    0.016272  0.277984   0.995695  0.890110
# 39    0.015292  0.265494   0.996086  0.879121
# 40    0.013107  0.398740   0.996869  0.879121
# 41    0.018877  0.236043   0.995303  0.912088
# 42    0.021670  0.320735   0.994521  0.890110
# 43    0.018207  0.413586   0.994912  0.879121
# 44    0.015424  0.154195   0.994912  0.956044
# 45    0.012420  0.286483   0.996477  0.890110
# 46    0.014065  0.236240   0.996477  0.934066
# 47    0.013531  0.232012   0.996477  0.923077
# 48    0.010403  0.300043   0.997260  0.934066
# 49    0.013853  0.191844   0.995303  0.934066

# %%
x = df.index
y1 = df['train_loss']
y2 = df['val_loss']

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.subplots_adjust(
     wspace=0.438,
)

plt.suptitle("Gráfico de Train e Val Loss")

axes[0].plot(x, y1, color="green")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Train Loss")


axes[1].plot(x, y2, color="darkblue")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Val Loss")


plt.show()

# %%
x = df.index
y1 = df['train_acc']
y2 = df['val_acc']

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.subplots_adjust(
     wspace=0.438
)

plt.suptitle("Gráfico de Train e Val Accuracy")

axes[0].plot(x, y1, color="green")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Train Accuracy")

axes[1].plot(x, y2, color="darkblue")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Val Accuracy")

plt.show()
